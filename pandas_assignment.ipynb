# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##1. Read superstore data

# %%
file=r'C:\Users\HP\Desktop\bizmetric\PYTHON PRACTICE\superstore.xls'
df=pd.read_excel(file)

# %%
df
# Out:
#           no       order _id Order Date  Ship Date       Ship Mode  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5        6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6        7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# ##2. find the index of the data

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %% [markdown]
# ###3. find the columns of the data

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ## if columns name is having space then remove the
# space and rename the column. find the various ways
# to rename the column

# %%
df.columns=df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['no', 'order__id', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ##display first 40 records

# %%
df.head(40)
# Out:
#       no       order__id Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0    NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1    2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2    3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3    4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4    5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5    6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6    7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7    8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8    9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9   10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10  11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...

# %% [markdown]
# ## display last 15 records from the data

# %%
df.tail(15)
# Out:
#           no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 9979  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9980  9981.0  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9981  9982.0  CA-2017-163566 2017-08-03 2017-08-06     First Class
# 9982  9983.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9983  9984.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984  9985.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# ##change the setting to display minimum 30 rows for
# given data

# %% [markdown]
# pd.

# %%
pd.options.display.min_rows=30
df
# Out:
#           no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5        6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6        7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7        8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 8        9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 9       10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10      11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 11      12.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 12      13.0  CA-2017-114412 2017-04-15 2017-04-20  Standard Class
# ...

# %% [markdown]
# ## change the display setting to minimum row as 3

# %%
pd.options.display.min_rows=15
df
# Out:
#           no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 0        NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5        6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6        7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# ##9. take a slice from the dataframe  based on the
# columns city, state, region, profit columns

# %%
df[['City','State','Region','Profit']]
# Out:
#                  City       State Region    Profit
# 0           Henderson    Kentucky  South   41.9136
# 1           Henderson    Kentucky  South  219.5820
# 2         Los Angeles  California   West    6.8714
# 3     Fort Lauderdale     Florida  South -383.0310
# 4     Fort Lauderdale     Florida  South    2.5164
# 5         Los Angeles  California   West   14.1694
# 6         Los Angeles  California   West    1.9656
# ...               ...         ...    ...       ...
# 9987           Athens     Georgia  South   28.7964
# 9988           Athens     Georgia  South   55.6470
# 9989            Miami     Florida  South    4.1028
# 9990       Costa Mesa  California   West   15.6332
# 9991       Costa Mesa  California   West   19.3932
# 9992       Costa Mesa  California   West   13.3200
# 9993      Westminster  California   West   72.9480
#
# [9994 rows x 4 columns]

# %% [markdown]
# ##10. Take a  slice based on data available at 1000 to
# 1500  position and columns  from 4 to 8

# %%
df.iloc[1000:1501,4:9]
# Out:
#            Ship_Mode Customer_ID    Customer_Name      Segment        Country
# 1000  Standard Class    FM-14290     Frank Merwin  Home Office  United States
# 1001        Same Day    RH-19495      Rick Hansen     Consumer  United States
# 1002        Same Day    RH-19495      Rick Hansen     Consumer  United States
# 1003        Same Day    RH-19495      Rick Hansen     Consumer  United States
# 1004  Standard Class    RA-19945        Ryan Akin     Consumer  United States
# 1005  Standard Class    JK-15730    Joe Kamberova     Consumer  United States
# 1006     First Class    MT-17815      Meg Tillman     Consumer  United States
# ...              ...         ...              ...          ...            ...
# 1494    Second Class    RF-19840  Roy Französisch     Consumer  United States
# 1495  Standard Class    JD-15790       John Dryer     Consumer  United States
# 1496  Standard Class    JD-15790       John Dryer     Consumer  United States
# ...

# %% [markdown]
# ##11. Rename the index starts from 1900 to end of
# the data

# %%
new_list=[]
num=1900
for i in range(len(df.index)):
    new_list.append(num)
    num+=1
df.index=new_list
df
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 1900      NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1901      2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1904      5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11887  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 11888  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 11889  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11891  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# 12. Take a slice from data based on index having
# name as 1920 , 1940, 1945, 1980, and columns as
# profit, state, category, sub-category, region

# %%
df.loc[[1920,1940,1945,1980],['Profit','State','Category','Sub-Category','Region']]
# Out:
#        Profit       State         Category Sub-Category   Region
# 1920   7.3840  California  Office Supplies      Binders     West
# 1940  41.7564       Texas       Technology       Phones  Central
# 1945   8.2062   Minnesota  Office Supplies      Binders  Central
# 1980   8.0352     Alabama  Office Supplies      Binders    South

# %% [markdown]
# 13. Check the data type of columns

# %%
df.dtypes
# Out:
# no                      float64
# order__id                object
# Order_Date       datetime64[ns]
# Ship_Date        datetime64[ns]
# Ship_Mode                object
# Customer_ID              object
# Customer_Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal_Code               int64
# Region                   object
# Product_ID               object
# Category                 object
# Sub-Category             object
# Product_Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# ##14. Find out the record for the month of jun-2014

# %%
#df[[df[Order_Date].dt.year==2014] & [df.Order_Date.dt.month==6]]
df[(df['Order_Date'].dt.year==2014) & (df['Order_Date'].dt.month==6)]
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1907      8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1908      9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1909     10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1910     11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1911     12.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11301  9402.0  CA-2014-159814 2014-06-24 2014-06-28  Standard Class
# 11596  9697.0  CA-2014-144281 2014-06-10 2014-06-15    Second Class
# 11664  9765.0  CA-2014-123855 2014-06-18 2014-06-23  Standard Class
# 11743  9844.0  CA-2014-163867 2014-06-03 2014-06-06     First Class
# 11744  9845.0  CA-2014-163867 2014-06-03 2014-06-06     First Class
# ...

# %% [markdown]
# #15. Calculate month wise average of profit.

# %%
#df.groupby([df['Order_Date'].dt.month,df['Order_Date'].dt.year])['Profit'].sum()
df.groupby([df['Order_Date'].dt.year,df['Order_Date'].dt.month])['Profit'].mean()
# Out:
# Order_Date  Order_Date
# 2014        1             31.015072
#             2             18.745835
#             3              3.176624
#             4             25.843224
#             5             22.448439
#             6             36.863144
#             7             -5.884494
#             8             34.758856
#             9             31.074998
#             10            21.687153
#             11            29.220525
#             12            32.315000
# 2015        1            -56.569086
#             2             43.966419
#             3             70.522448
#             4             26.171851
#             5             31.971705
#             6             24.170704
#             7             23.490345
#             8             33.684330
#             9             28.017620
#             10            16.972084
#             11            38.502433
#             12            25.370145
# 2016        1             31.739588
# ...

# %% [markdown]
# #16. Create the new data frame for California

# %%
new_df=df[df['State']=='California']
new_df
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1907      8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1908      9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1909     10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1910     11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11878  9979.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 11879  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 11886  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11891  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# #Find sum of sales

# %%
df['Sales'].sum()
# Out:
# 2297200.8603000003

# %% [markdown]
# #Find state wise sum of sales.

# %%
df.groupby('State')['Sales'].sum()
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %% [markdown]
# ###19. Find month wise sum  of sales

# %%
df.groupby([df['Order_Date'].dt.year, df['Order_Date'].dt.month])['Sales'].sum()
# Out:
# Order_Date  Order_Date
# 2014        1              14236.8950
#             2               4519.8920
#             3              55691.0090
#             4              28295.3450
#             5              23648.2870
#             6              34595.1276
#             7              33946.3930
#             8              27909.4685
#             9              81777.3508
#             10             31453.3930
#             11             78628.7167
#             12             69545.6205
# 2015        1              18174.0756
#             2              11951.4110
#             3              38726.2520
#             4              34195.2085
#             5              30131.6865
#             6              24797.2920
#             7              28765.3250
#             8              36898.3322
#             9              64595.9180
#             10             31404.9235
#             11             75972.5635
#             12             74919.5212
# ...

# %% [markdown]
# #20. Find country wise and city wise average profit

# %%
df.groupby(['Country','City'])['Profit'].mean()
# Out:
# Country        City
# United States  Aberdeen         6.630000
#                Abilene         -3.758400
#                Akron           -8.887410
#                Albuquerque     45.292007
#                Alexandria      19.913644
#                Allen           -9.969375
#                Allentown      -32.350057
#                                  ...
#                Woodland        11.128267
#                Woodstock       15.998580
#                Woonsocket      19.669775
#                Yonkers        184.517047
#                York           -20.433840
#                Yucaipa         13.208000
#                Yuma          -116.497725
# Name: Profit, Length: 531, dtype: float64

# %% [markdown]
# #21. Calculate region wise average profit.

# %%
df.groupby('Region')['Profit'].mean()
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %% [markdown]
# #22. Find the ship mode which is more profitable.

# %%
df.groupby('Ship_Mode')['Profit'].sum().idxmax()
#df.columns
# Out:
# 'Standard Class'

# %% [markdown]
# #23. Create a new data frame where loss is recorded

# %%
new_df1=df[df['Profit']<0]
new_df1
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 1903      4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1914     15.0  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 1915     16.0  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 1923     24.0  US-2017-156909 2017-07-16 2017-07-18    Second Class
# 1927     28.0  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 1928     29.0  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 1932     33.0  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# ...       ...             ...        ...        ...             ...
# 11812  9913.0  CA-2015-132388 2015-10-10 2015-10-12     First Class
# 11819  9920.0  CA-2016-149272 2016-03-15 2016-03-19  Standard Class
# 11820  9921.0  CA-2016-149272 2016-03-15 2016-03-19  Standard Class
# 11821  9922.0  CA-2014-111360 2014-11-24 2014-11-30  Standard Class
# 11831  9932.0  CA-2015-104948 2015-11-13 2015-11-17  Standard Class
# ...

# %% [markdown]
# #24. Find category wise sub category wise sales

# %%
df.groupby(['Category','Sub-Category'])['Sales'].sum()
# Out:
# Category         Sub-Category
# Furniture        Bookcases       114879.9963
#                  Chairs          328449.1030
#                  Furnishings      91705.1640
#                  Tables          206965.5320
# Office Supplies  Appliances      107532.1610
#                  Art              27118.7920
#                  Binders         203412.7330
#                  Envelopes        16476.4020
#                  Fasteners         3024.2800
#                  Labels           12486.3120
#                  Paper            78479.2060
#                  Storage         223843.6080
#                  Supplies         46673.5380
# Technology       Accessories     167380.3180
#                  Copiers         149528.0300
#                  Machines        189238.6310
#                  Phones          330007.0540
# Name: Sales, dtype: float64

# %% [markdown]
# 25. Create a data frame for record where discount is 0

# %%
new_df3=df[df['Discount']==0]
new_df3
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 1900      NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1901      2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1909     10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1916     17.0  CA-2014-105893 2014-11-11 2014-11-18  Standard Class
# ...       ...             ...        ...        ...             ...
# 11885  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 11886  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 11887  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 11888  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# Create a data frame where order date and ship date both are in JAN-2014

# %%
df[(df['Order_Date'].dt.year==2014) & (df['Order_Date'].dt.month==1) &(df['Ship_Date'].dt.year==2014) & (df['Ship_Date'].dt.month==1)]
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 2492    593.0  CA-2014-135405 2014-01-09 2014-01-13  Standard Class
# 2493    594.0  CA-2014-135405 2014-01-09 2014-01-13  Standard Class
# 2616    717.0  CA-2014-130092 2014-01-11 2014-01-14     First Class
# 2639    740.0  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 2640    741.0  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 2641    742.0  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 2663    764.0  CA-2014-162775 2014-01-13 2014-01-15    Second Class
# ...       ...             ...        ...        ...             ...
# 10049  8150.0  CA-2014-167997 2014-01-26 2014-01-29     First Class
# 10050  8151.0  CA-2014-167997 2014-01-26 2014-01-29     First Class
# 11055  9156.0  CA-2014-102645 2014-01-23 2014-01-28  Standard Class
# 11528  9629.0  CA-2014-118192 2014-01-13 2014-01-18  Standard Class
# 11529  9630.0  CA-2014-118192 2014-01-13 2014-01-18  Standard Class
# ...

# %% [markdown]
# Find records having profit for consumer segment.

# %%
df[(df['Segment']=='Consumer') & (df['Profit']>0)]
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 1900      NaN             NaN 2016-11-08 2016-11-11    Second Class
# 1901      2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1904      5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1907      8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 1908      9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...       ...             ...        ...        ...             ...
# 11885  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 11886  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 11889  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 11890  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 11891  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# Generate new data frame for every state (hint: dynamic variable creation)

# %%
state_dfs = {}
for state, group in df.groupby('State'):
    state_dfs[state] = group.reset_index(drop=True)
# Out:
#          no       order__id Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0      15.0  US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
# 1      16.0  US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
# 2      35.0  CA-2017-107727 2017-10-19 2017-10-23    Second Class    MA-17560
# 3      36.0  CA-2016-117590 2016-12-08 2016-12-10     First Class    GH-14485
# 4      37.0  CA-2016-117590 2016-12-08 2016-12-10     First Class    GH-14485
# 5      38.0  CA-2015-117415 2015-12-27 2015-12-31  Standard Class    SN-20710
# 6      39.0  CA-2015-117415 2015-12-27 2015-12-31  Standard Class    SN-20710
# ..      ...             ...        ...        ...             ...         ...
# 978  9904.0  CA-2014-122609 2014-11-12 2014-11-18  Standard Class    DP-13000
# 979  9905.0  CA-2014-122609 2014-11-12 2014-11-18  Standard Class    DP-13000
# 980  9920.0  CA-2016-149272 2016-03-15 2016-03-19  Standard Class    MY-18295
# ...

# %% [markdown]
# #Generate the region wise, state wise average profit and sales and then extract information for east region.

# %%
df.columns
df_5=df.groupby(['State','Region'])[['Profit','Sales']].mean()
temp = df_5.reset_index()
temp[temp['Region']=='East']
# Out:
#                    State Region      Profit       Sales
# 5            Connecticut   East   42.823071  163.223866
# 6               Delaware   East  103.930988  285.948635
# 7   District of Columbia   East  105.958930  286.502000
# 17                 Maine   East   56.810775  158.816250
# 18              Maryland   East   66.963608  225.766886
# 19         Massachusetts   East   50.262975  212.106919
# 27         New Hampshire   East   63.203807  270.093481
# 28            New Jersey   East   75.176260  275.110092
# 30              New York   East   65.637011  275.599531
# 33                  Ohio   East  -36.186304  166.861697
# 36          Pennsylvania   East  -26.507598  198.487077
# 37          Rhode Island   East  130.100523  404.070643
# 43               Vermont   East  204.088936  811.760909
# 46         West Virginia   East   46.480400  302.456000

# %% [markdown]
#  Find all record for furniture delivered in Texas

# %%
df[(df['Category']=='Furniture') & (df['State']=='Texas')]
# Out:
#            no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 1936     37.0  CA-2016-117590 2016-12-08 2016-12-10     First Class
# 1938     39.0  CA-2015-117415 2015-12-27 2015-12-31  Standard Class
# 1939     40.0  CA-2015-117415 2015-12-27 2015-12-31  Standard Class
# 1976     77.0  US-2017-118038 2017-12-09 2017-12-11     First Class
# 1978     79.0  US-2014-147606 2014-11-26 2014-12-01    Second Class
# 2024    125.0  US-2014-152030 2014-12-26 2014-12-28    Second Class
# 2067    168.0  CA-2014-139892 2014-09-08 2014-09-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 11690  9791.0  CA-2017-144491 2017-03-27 2017-04-01  Standard Class
# 11692  9793.0  CA-2014-127166 2014-05-21 2014-05-23    Second Class
# 11731  9832.0  CA-2014-113257 2014-12-16 2014-12-18    Second Class
# 11734  9835.0  CA-2016-126627 2016-10-10 2016-10-12     First Class
# 11803  9904.0  CA-2014-122609 2014-11-12 2014-11-18  Standard Class
# ...
